# %%
import os,sys
#Change and check directory
os.chdir('C:\WGU\D207')
os.getcwd()
# Out:
# 'C:\\WGU\\D207'

# %%
#import necessary libraries
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

#load the data frame
churn = pd.read_csv('churn_clean.csv')
churn.describe()
# Out:
#          CaseOrder           Zip           Lat           Lng     Population  \
# count  10000.00000  10000.000000  10000.000000  10000.000000   10000.000000
# mean    5000.50000  49153.319600     38.757567    -90.782536    9756.562400
# std     2886.89568  27532.196108      5.437389     15.156142   14432.698671
# min        1.00000    601.000000     17.966120   -171.688150       0.000000
# 25%     2500.75000  26292.500000     35.341828    -97.082812     738.000000
# 50%     5000.50000  48869.500000     39.395800    -87.918800    2910.500000
# 75%     7500.25000  71866.500000     42.106908    -80.088745   13168.000000
# max    10000.00000  99929.000000     70.640660    -65.667850  111850.000000
#
#          Children           Age         Income  Outage_sec_perweek  \
# count  10000.0000  10000.000000   10000.000000        10000.000000
# mean       2.0877     53.078400   39806.926771           10.001848
# std        2.1472     20.698882   28199.916702            2.976019
# ...

# %%
#Ttest
Sample_A = churn[churn.Churn == "Yes"]['Email']
Sample_B = churn[churn.Churn == "No"]['Email']
t_result = stats.ttest_ind(Sample_A, Sample_B)

# %%
Sample_A.describe()
# Out:
# count    2650.000000
# mean       12.078113
# std         3.008534
# min         2.000000
# 25%        10.000000
# 50%        12.000000
# 75%        14.000000
# max        23.000000
# Name: Email, dtype: float64

# %%
Sample_B.describe()
# Out:
# count    7350.000000
# mean       11.993605
# std         3.032026
# min         1.000000
# 25%        10.000000
# 50%        12.000000
# 75%        14.000000
# max        22.000000
# Name: Email, dtype: float64

# %%
print(t_result)
# Out:
# TtestResult(statistic=1.2325944156039008, pvalue=0.21775610450205743, df=9998.0)

# %%
#Univariate Statistics

# %%
#Distribution of Continuous Variables
monthly_charge_stats = churn['Email'].describe()
tenure_stats = churn['Contacts'].describe()

# Box plot for Email and Contacts
fig, axes = plt.subplots(1, 2, figsize=(10, 6))
axes[0].boxplot(churn['Email'])
axes[0].set_title('Box Plot - Emails')
axes[0].set_ylabel('Number of Emails')
axes[1].boxplot(churn['Contacts'])
axes[1].set_title('Box Plot - Contacts')
axes[1].set_ylabel('Number of Contacts')

# Display the summary statistics
print("Summary Statistics for Emails:\n", monthly_charge_stats)
print("\nSummary Statistics for Contacts:\n", tenure_stats)

# Show the box plots
plt.tight_layout()
plt.show()
# Out:
# Summary Statistics for Emails:
#  count    10000.000000
# mean        12.016000
# std          3.025898
# min          1.000000
# 25%         10.000000
# 50%         12.000000
# 75%         14.000000
# max         23.000000
# Name: Email, dtype: float64
#
# Summary Statistics for Contacts:
#  count    10000.000000
# mean         0.994200
# std          0.988466
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          7.000000
# Name: Contacts, dtype: float64

# %%
#Distribution of Categorical Variables
churn['Churn'].value_counts().plot.bar(rot=0)
plt.title('Churn')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.show()

order = [1,2,3,4,5,6,7]
churn['Item7'].value_counts().loc[order].plot.bar(rot=0)
plt.title('Courteous Exchange')
plt.xlabel('Courteous Exchange Rating')
plt.ylabel('Count')
plt.show()

# %%
#Bivariate Statistics

# %%
#Distribution of Continuous Variables
churn.plot(x = 'Email', y = 'Contacts', kind = 'scatter')
plt.title("Emails and Contacts")
plt.show()

# %%
# Distribution of Catagorical Variables
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=churn, x='Churn', hue='Item7')
plt.title('Bar Plot - Courteous Exchange by Churn')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.legend(title='Courteous Exchange', loc='upper right')
plt.tight_layout()  # Adjusts the plot's layout
plt.show()
